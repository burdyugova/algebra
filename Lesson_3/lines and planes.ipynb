# %% [markdown]
# ## Задание 2.1
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
# Напишите код на Python, реализующий расчет длины вектора, заданного его координатами

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
a = np.array([10, 10, 10])
b = np.array([0, 0, -10])
a+b
# Out:
# array([10, 10,  0])

# %% [markdown]
# ## Задание 2.3
# Напишите код на Python, реализующий построение графиков: окружности, эллипса, гиперболы.

# %%
# %matplotlib inline
x = np.linspace(-10, 10, 51)
y = x**2
plt.plot(x, y)
plt.show()

# %%
circle1 = plt.Circle((0, 0), 0.2, fill=False)

ax=plt.gca()
ax.add_patch(circle1)
plt.axis('scaled')
plt.show()

# %%
a = 150
b = 90
dx = turtle.xcor()
dy = turtle.ycor()
for deg in range(361):
    rad = math.radians(deg)
    x = a * math.sin(rad) + dx
    y = -b * math.cos(rad) + b + dy
    turtle.goto(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-5703b4e9c3e5> in <module>
#       1 a = 150
#       2 b = 90
# ----> 3 dx = turtle.xcor()
#       4 dy = turtle.ycor()
#       5 for deg in range(361):
#
# NameError: name 'turtle' is not defined
