# %% [markdown]
# ## Задание 2.1
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
# Напишите код на Python, реализующий расчет длины вектора, заданного его координатами

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
a = np.array([10, 10, 10])
b = np.array([0, 0, -10])
a+b
# Out:
# array([10, 10,  0])

# %% [markdown]
# ## Задание 2.3
# Напишите код на Python, реализующий построение графиков: окружности, эллипса, гиперболы.

# %%
# %matplotlib inline
x = np.linspace(-10, 10, 51)
y = x**2
plt.plot(x, y)
plt.show()

# %%
circle = plt.Circle((0, 0), 0.2, color = 'blue', fill = False)

ax = plt.gca()
ax.add_patch(circle)
plt.axis('scaled')
plt.show()

# %%
from math import pi

u=1.     #x-position of the center
v=0.5    #y-position of the center
a=2.     #radius on the x-axis
b=1.5    #radius on the y-axis

t = np.linspace(0, 2*pi, 100)
plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )

plt.show()

# %% [markdown]
# ## Задание 2.5
# Нарисуйте трехмерный график двух параллельных плоскостей.

# %%
X, Y = np.meshgrid([1,2,3], [4,5,6,7])



plt.plot(X, Y)
# Out:
# [<matplotlib.lines.Line2D at 0x115d7e4e0>,
#  <matplotlib.lines.Line2D at 0x115d7e630>,
#  <matplotlib.lines.Line2D at 0x115d7e780>]
